# %% [markdown]
# # Matemática e Estatística - MATRIZES
# ## Prof. Ujeverson Tavares

# %% [markdown]
# ## Como calcular a distância entre dois pontos no plano usando Python - Python para Geometria Analítica

# %% [markdown]
# ### Vamos analisar a imagem a seguir:

# %% [markdown]
# ![planoCartesiano.jpg](attachment:planoCartesiano.jpg)

# %% [markdown]
# ### Fórmula da distância entre dois pontos

# %% [markdown]
# $ d_{A,B} = \sqrt{(x_A - x_B)^2 + (y_A - y_B)^2}  $

# %%
import math

# %%
A = (3,6)
B = (9,4)

# %%
d = math.sqrt((A[0]-B[0])**2 + (A[1]-B[1])**2)
print(round(d, 2))
# Out:
# 6.32

# %%
# valor por km rodado
fixo = 5.65

# %%
# valor a pagar

# %%
print(round(d*fixo,2))
# Out:
# 35.73

# %% [markdown]
# ### Usando a função _math.dist()_ para encontrar a distância euclidiana entre dois pontos

# %%
from math import dist

# %%
distance = dist(A, B)
distance
# Out:
# 6.324555320336759

# %% [markdown]
# ### Usando o módulo NumPy para encontrar a distância euclidiana entre dois pontos

# %%
import numpy as np

# %%
A = np.array([[3,6]])
B = np.array([[9,4]])

# %%
dist = np.linalg.norm(A - B)
dist
# Out:
# 6.324555320336759

# %% [markdown]
# ### Usando a biblioteca scipy tem muitas funções para cálculos matemáticos e científicos. A função _distance.euclidean()_ retorna a distância euclidiana entre dois pontos.

# %%
from scipy.spatial import distance as dist

# %%
A = [3,6]
B = [9,4]

# %%
distancia = dist.euclidean(A, B)
distancia
# Out:
# 6.324555320336759
