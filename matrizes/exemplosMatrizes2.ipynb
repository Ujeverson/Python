# %%
import numpy as np

# %% [markdown]
# ## Tipo de matrizes

# %% [markdown]
# ## Matriz linha

# %%
A = np.array([[1, 2, -3]])
print("A=",A,"\nDimensão:",np.shape(A))
# Out:
# A= [[ 1  2 -3]]
# Dimensão: (1, 3)

# %% [markdown]
# ## Matriz coluna

# %%
B = np.array([[1], [2], [-3]])
print("B=",B,"\nDimensão:",np.shape(B))
# Out:
# A= [[ 1]
#  [ 2]
#  [-3]]
# Dimensão: (3, 1)

# %% [markdown]
# ## Matriz quadrada

# %%
C = np.array([[1.2, -3, 5],[-4, -8, 12], [-5, 8, 2]], dtype = int)
print("C=\n",C,"\nDimensão:",np.shape(C))
# Out:
# C=
#  [[ 1 -3  5]
#  [-4 -8 12]
#  [-5  8  2]]
# Dimensão: (3, 3)

# %%
D= np.array([[1, -3, 5],[-4, -8, 12], [-5, 8, 2]])
D
# Out:
# array([[ 1, -3,  5],
#        [-4, -8, 12],
#        [-5,  8,  2]])

# %%
D[2][0]
# Out:
# -5

# %%
D[2,0]
# Out:
# -5

# %%
a = int(input("Digite o valor que quer mudar:"))
# Out:
# Digite o valor que quer mudar:5

# %%
a
# Out:
# 5

# %%
D[2,0] = a
D
# Out:
# array([[ 1, -3,  5],
#        [-4, -8, 12],
#        [ 5,  8,  2]])

# %%
C = np.array([[4],[7],[3],[4]])
C
# Out:
# array([[4],
#        [7],
#        [3],
#        [4]])

# %%
a = C[0,0]
c = C[1,0]
s = C[2,0]
t = C[3,0]

# %%
muda_a = int(input("Digite o novo valor da porção de arroz:"))
C[0,0] = muda_a
# Out:
# Digite o novo valor da porção de arroz:3

# %%
C
# Out:
# array([[3],
#        [7],
#        [3],
#        [4]])

# %%
muda_c = int(input("Digite o novo valor da porção de arroz:"))
C[1,0] = muda_c
# Out:
# Digite o novo valor da porção de arroz:4

# %%
C
# Out:
# array([[3],
#        [4],
#        [3],
#        [4]])

# %%
P = np.array([[2, 2, 1, 1],[1, 2, 1, 1],[2, 2, 0,3]])
print(P)
# Out:
# [[2 2 1 1]
#  [1 2 1 1]
#  [2 2 0 3]]

# %%
C = np.array([[4],[7],[3],[4]])
C
# Out:
# array([[4],
#        [7],
#        [3],
#        [4]])

# %%
P_C = np.dot(P,C)
P_C
# Out:
# array([[29],
#        [25],
#        [34]])

# %%
print("Prato 1 vale R$",P_C[0,0])
print("Prato 2 vale R$",P_C[1,0])
print("Prato 3 vale R$",P_C[2,0])
# Out:
# Prato 1 vale R$ 29
# Prato 2 vale R$ 25
# Prato 3 vale R$ 34
